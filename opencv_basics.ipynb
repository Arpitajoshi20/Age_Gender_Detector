# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
import cv2
from matplotlib import pyplot as pyplot

# %% [markdown]
# PLOTTING

# %%
img1=cv2.imread("Resources/Data/z.jpg")

# %%
plt.imshow(img1)

# %% [markdown]
# Arithmetic Operation

# %%
img2=cv2.imread("Resources/Data/n.jpg")

# %%
plt.imshow(img2)

# %%
result=img1+img2

# %%
plt.imshow(result)

# %% [markdown]
# MULTILICATION

# %%
result=img1*img2

# %%
plt.imshow(result)

# %% [markdown]
# DIVISION

# %%
result=img1/img2
plt.imshow(result)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20032\1580248168.py:1: RuntimeWarning: divide by zero encountered in divide
#   result=img1/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# SUBTRACTION

# %%
result=img1-img2
plt.imshow(result)

# %% [markdown]
# BURRING

# %%
img3=cv2.imread("Resources/Data/x.jpg")
img=cv2.cvtColor(img3,cv2.COLOR_BGR2HSV)
figure_size=7
result=cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2BGR)),plt.title("ORIGINAL")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(result,cv2.COLOR_HSV2BGR)),plt.title("BLURRED")
plt.xticks([]),plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ZOOM

# %%
import cv2

# %%
img1=cv2.imread("Resources/Data/v.jpg")

# %%
from matplotlib import pyplot as plt

# %%
(height,width)=img1.shape[0:2]
zoom=cv2.resize(img1,None,fx=1.5,fy=1.5,interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom=cv2.resize(img1,(int(width*2),(height*2)),interpolation=cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# ROTATE

# %%
m=cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate=cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %% [markdown]
# TRANSLATE

# %%
import numpy as np

# %%
m=np.float32([[1,0,50],[0,1,100]])
dst=cv2.warpAffine(img1,m,(height,width))
plt.imshow(dst)
